# %% [markdown]
# # Different Naive Approaches
#  All the approaches are based on the provided observation metadata and does not need any training.

# %% [markdown]
# ## Loading Metadata
# First we load all the metadata and import some very basic libraries.

# %%
import pandas as pd
from tqdm import tqdm
import os
tqdm.pandas()
os.chdir("../../")
# Load train and test metadata
po_train = pd.read_csv('Dataset/geolifeclef-2024/GLC24_P0_metadata_train.csv', dtype={'speciesId':int})
pa_train = pd.read_csv('Dataset/geolifeclef-2024/GLC24_PA_metadata_train.csv', dtype={'speciesId':int})
test = pd.read_csv('Dataset/geolifeclef-2024/GLC24_PA_metadata_test.csv',  dtype={'speciesId':int})

# %% [markdown]
# #  Upscale GPS to higher-level regions.
# Location plays a crutial role in the prediction. Therefore, I will use [reverse_geocoder](https://github.com/thampiman/reverse-geocoder) to upscale the GPS to higher ranks such as district and county.

# %%
# !pip install reverse_geocoder
# Out:
# Requirement already satisfied: reverse_geocoder in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from reverse_geocoder) (1.26.4)
# Requirement already satisfied: scipy>=0.17.1 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from reverse_geocoder) (1.13.1)

# %%
from joblib import Parallel, delayed
import multiprocessing
import reverse_geocoder

n_jobs = multiprocessing.cpu_count()

def upscale_gps(survey):

    return dict(**reverse_geocoder.search((survey.lat, survey.lon), mode=1)[0], **{'surveyId': survey.surveyId})
    

def update_metadata():
    pass

# %% [markdown]
# ### Update PA Train Surveys

# %%
pa_train_surveys = pa_train.drop_duplicates("surveyId").reset_index(drop=True)

pa_location_data = Parallel(n_jobs=n_jobs)(
            delayed(upscale_gps)(survey)
            for _, survey in tqdm(pa_train_surveys[["lon", "lat", "surveyId"]].iterrows(), total=len(pa_train_surveys))
        )

pa_location_data = pd.DataFrame(pa_location_data).rename(
    columns={"location_lvl3":"location_name",
             "cc": "countryCode",
             "admin1":"county",
             "admin2": "district"}
)
pa_location_data.head()
# Out:
#   0%|          | 0/88987 [00:00<?, ?it/s]
# 100%|██████████| 88987/88987 [00:45<00:00, 1946.77it/s]
#         lat       lon       name                county  \
# 0  43.10759   3.08651   Gruissan  Languedoc-Roussillon
# 1  56.88536   9.83839   Stovring         North Denmark
# 2   55.6268   8.28757     Oksbol         South Denmark
# 3      43.4  -0.38333  Sauvagnon             Aquitaine
# 4  45.82231  -0.50539    Ecoyeux      Poitou-Charentes
#
#                                district countryCode  surveyId
# 0                 Departement de l'Aude          FR     212.0
# 1                        Rebild Kommune          DK     222.0
# 2                         Varde Kommune          DK     243.0
# 3  Departement des Pyrenees-Atlantiques          FR     324.0
# 4   Departement de la Charente-Maritime          FR     333.0

# %%
# Lets check the granularity.
print(f"Number of unique countires: {len(pa_location_data.countryCode.unique())}")
print(f"Number of unique counties: {len(pa_location_data.county.unique())}")
print(f"Number of unique districts: {len(pa_location_data.district.unique())}")
print(f"Number of unique names: {len(pa_location_data.name.unique())}")
# Out:
# Number of unique countires: 33
# Number of unique counties: 208
# Number of unique districts: 772
# Number of unique names: 5752

# %%
pa_location_data.drop(columns=["lat", "lon"])
pa_train = pd.merge(pa_train, pa_location_data.drop(columns=["lat", "lon"]), on=['surveyId'], how='inner')

# %% [markdown]
# ### Update Test Surveys

# %%
test_location_data = Parallel(n_jobs=n_jobs)(
            delayed(upscale_gps)(survey)
            for _, survey in tqdm(test[["lon", "lat", "surveyId"]].iterrows(), total=len(test))
        )

test_location_data = pd.DataFrame(test_location_data).rename(
    columns={"location_lvl3":"location_name",
             "cc": "countryCode",
             "admin1":"county",
             "admin2": "district"}
)
test_location_data.head()
# Out:
# 100%|██████████| 4716/4716 [00:02<00:00, 1981.65it/s]
#         lat       lon            name               county  \
# 0  57.10854  10.02215         Vodskov        North Denmark
# 1  46.25115   7.34558         Saviese               Valais
# 2  42.54277   1.73361  Pas de la Casa               Encamp
# 3  46.15667  11.72998  Canal San Bovo  Trentino-Alto Adige
# 4  55.83977   9.24998            Give        South Denmark
#
#               district countryCode  surveyId
# 0       Alborg Kommune          DK     642.0
# 1        Sion District          CH    1792.0
# 2                               AD    3256.0
# 3  Provincia di Trento          IT    3855.0
# 4        Vejle Kommune          DK    4889.0

# %%
test_location_data.drop(columns=["lat", "lon"])
test = pd.merge(test, test_location_data.drop(columns=["lat", "lon"]), on=['surveyId'], how='inner')

# %% [markdown]
# #  First Approach Top25 PA species **[0.11505]**

# %%
test['predictions'] = ' '.join([str(species) for species in pa_train.speciesId.value_counts().nlargest(25).index])

output = test[['surveyId','predictions']]
output.to_csv('research/Baseline_experiments/outputs/naive-approach/output-top25-pa.csv', index=False)
output
# Out:
#       surveyId                                        predictions
# 0          642  540 4397 254 4499 10317 2885 1964 10600 10073 ...
# 1         1792  540 4397 254 4499 10317 2885 1964 10600 10073 ...
# 2         3256  540 4397 254 4499 10317 2885 1964 10600 10073 ...
# 3         3855  540 4397 254 4499 10317 2885 1964 10600 10073 ...
# 4         4889  540 4397 254 4499 10317 2885 1964 10600 10073 ...
# ...        ...                                                ...
# 4711   3915838  540 4397 254 4499 10317 2885 1964 10600 10073 ...
# 4712   3916502  540 4397 254 4499 10317 2885 1964 10600 10073 ...
# 4713   3917793  540 4397 254 4499 10317 2885 1964 10600 10073 ...
# 4714   3918865  540 4397 254 4499 10317 2885 1964 10600 10073 ...
# 4715   3919234  540 4397 254 4499 10317 2885 1964 10600 10073 ...
#
# [4716 rows x 2 columns]

# %% [markdown]
# # Second Approach: Top-25 species per Country (PA) [**0.15677**]

# %%
# !pip install -U ipywidgets swifter
# Out:
# Requirement already satisfied: ipywidgets in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (8.1.3)
# Requirement already satisfied: swifter in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (1.4.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipywidgets) (8.24.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipywidgets) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipywidgets) (3.0.11)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from swifter) (2.2.2)
# Requirement already satisfied: psutil>=5.6.6 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from swifter) (5.9.0)
# Requirement already satisfied: dask>=2.10.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2024.5.1)
# Requirement already satisfied: tqdm>=4.33.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from swifter) (4.66.4)
# Requirement already satisfied: click>=8.1 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (2024.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (24.0)
# Requirement already satisfied: partd>=1.2.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (7.1.0)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.1.1)
# Requirement already satisfied: decorator in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.11.0)
# Requirement already satisfied: colorama in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from pandas>=1.0.0->swifter) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from pandas>=1.0.0->swifter) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from pandas>=1.0.0->swifter) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from pandas>=1.0.0->swifter) (2024.1)
# Requirement already satisfied: pyarrow>=7.0.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from dask-expr<1.2,>=1.1->dask[dataframe]>=2.10.0->swifter) (16.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from importlib-metadata>=4.13.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (3.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: locket in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from partd>=1.2.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: wcwidth in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->swifter) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\yashr\anaconda3\envs\geoenv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)

# %%
import swifter
tqdm.pandas()

def get_topk_pa_species(country, k=25):
    query = list(pa_train.loc[(pa_train.country == country), "speciesId"].value_counts().nlargest(k).index)
    query.sort()
    return " ".join([str(c) for c in query]) if len(query) > 0 else "0"

test["predictions"] = test.swifter.apply(lambda test_observation: get_topk_pa_species(test_observation["country"]), axis=1)
output = test[["surveyId","predictions"]]

output.to_csv("research/Baseline_experiments/outputs/naive-approach/output-pa-country-top25.csv", index=False)
output
# Out:
# Pandas Apply:   0%|          | 0/4716 [00:00<?, ?it/s]
#       surveyId                                        predictions
# 0          642  254 540 581 1964 2885 4397 4499 4638 6310 6491...
# 1         1792  262 838 1015 1018 1092 1254 1497 3451 3639 374...
# 2         3256  146 963 981 1888 2474 4498 4609 4871 5071 5412...
# 3         3855  963 1677 1736 2386 2474 2715 3125 3166 4659 54...
# 4         4889  254 540 581 1964 2885 4397 4499 4638 6310 6491...
# ...        ...                                                ...
# 4711   3915838  254 540 1539 2025 2885 3722 4397 4499 5386 607...
# 4712   3916502  254 540 1539 2025 2885 3722 4397 4499 5386 607...
# 4713   3917793  423 1018 1254 1497 1818 3123 3722 4748 4758 53...
# 4714   3918865  254 540 581 1964 2885 4397 4499 4638 6310 6491...
# 4715   3919234  423 1018 1254 1497 1818 3123 3722 4748 4758 53...
#
# [4716 rows x 2 columns]

# %% [markdown]
# # Third Approach: Top-25 species per district (PA) [**0.20001**]

# %%
import swifter
tqdm.pandas()

def get_topk_pa_species(district, k=25):
    query = list(pa_train.loc[(pa_train.district == district), "speciesId"].value_counts().nlargest(k).index)
    query.sort()
    return " ".join([str(c) for c in query]) if len(query) > 0 else "0"

test["predictions"] = test.swifter.apply(lambda test_observation: get_topk_pa_species(test_observation["district"]), axis=1)
output = test[["surveyId","predictions"]]

output.to_csv("research/Baseline_experiments/outputs/naive-approach/output-pa-district-top25.csv", index=False)
output
# Out:
# Pandas Apply:   0%|          | 0/4716 [00:00<?, ?it/s]
#       surveyId                                        predictions
# 0          642  254 340 540 581 1964 2885 4397 4499 4638 6310 ...
# 1         1792                                                  0
# 2         3256  423 559 694 963 1015 1086 1497 1818 2753 2891 ...
# 3         3855  53 423 963 1162 2184 2474 2799 4109 4112 4734 ...
# 4         4889  254 540 581 843 958 963 1910 1964 2025 2142 28...
# ...        ...                                                ...
# 4711   3915838  254 540 581 1170 2025 2885 3361 4483 4492 4499...
# 4712   3916502  340 540 1545 1716 2025 2761 2885 2922 3226 385...
# 4713   3917793  1092 1139 1254 1851 2747 3043 5146 5412 6208 6...
# 4714   3918865  53 254 791 843 963 1964 2025 2823 3294 5114 51...
# 4715   3919234  392 1092 1139 1254 2747 3043 3470 5412 5895 67...
#
# [4716 rows x 2 columns]

# %% [markdown]
# # Fourth Approach: Top-25 species per district & biogeographical zones (PA) [**0.20567**]

# %%
def get_topk_pa_species(district, region, k=25):
    query = list(pa_train.loc[(pa_train.region == region) & (pa_train.district == district), "speciesId"].value_counts().nlargest(k).index)
    query.sort()
    return " ".join([str(c) for c in query]) if len(query) > 0 else "0"

test["predictions"] = test.swifter.apply(lambda test_observation: get_topk_pa_species(test_observation["district"], test_observation["region"]), axis=1)
output = test[["surveyId","predictions"]]

output.to_csv("research/Baseline_experiments/outputs/naive-approach/output-pa-district+region.csv", index=False)
output
# Out:
# Pandas Apply:   0%|          | 0/4716 [00:00<?, ?it/s]
#       surveyId                                        predictions
# 0          642  254 340 540 581 1964 2885 4397 4499 4638 6310 ...
# 1         1792                                                  0
# 2         3256  53 544 791 963 1677 2002 3661 4946 5022 5071 5...
# 3         3855  53 423 963 1162 2184 2474 2799 4109 4112 4734 ...
# 4         4889  254 540 958 963 976 1910 1964 2025 2142 2398 2...
# ...        ...                                                ...
# 4711   3915838  254 540 581 1170 2025 2885 3361 4483 4492 4499...
# 4712   3916502  340 540 1545 1716 2025 2761 2885 2922 3226 385...
# 4713   3917793  963 1092 1139 1254 1851 2747 3043 5412 6208 66...
# 4714   3918865  53 254 791 843 963 1964 2025 2823 3294 5114 51...
# 4715   3919234  392 1092 1254 2747 3043 3470 5412 6067 6487 67...
#
# [4716 rows x 2 columns]
